# %%
import sys
sys.path.append("../pandemic")
from pandemic import Pandemic

# %%
# set up game
pd = Pandemic()

# %%
pd.plot_model(figsize = (16,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/soap/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('red,', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.virtualenvs/soap/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4231             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4232                 colors = mcolors.to_rgba_array(c)
#    4233                 n_elem = colors.shape[0]
#
# ...
